f0\x9f\x98\x82\xf0\x9f\x98\x82\xf0\x9f\x98\x82\n', '12/01/18, 00:20 - Jayesh-CSE: Vasu bhai maar li jaaegi 11 nhi pahuche toh\n', '12/01/18, 00:20 - Jayesh-CSE: \xf0\x9f\x98\x86\xf0\x9f\x98\x86\n', '12/01/18, 00:20 - Jayesh-CSE: \xf0\x9f\xa4\xaa\n', '12/01/18, 00:22 - Vasu Dev-129: Sallo sb post  pr like kro\n', '12/01/18, 00:22 - Jayesh-CSE: Jaroori h?\n', '12/01/18, 00:23 - Siddarth-IT: Team drohi\n', '12/01/18, 00:23 - Siddarth-IT: Saala\n', '12/01/18, 00:24 - Jayesh-CSE: \xf0\x9f\xa4\xab\n', '12/01/18, 00:24 - Siddarth-IT: \xf0\x9f\xa4\xac\xf0\x9f\xa4\xac\xf0\x9f\xa4\xac\n', '12/01/18, 00:25 - Gaurav-IT: \xf0\x9f\xa4\xa3\n', '13/01/18, 09:46 - Vasu Dev-129: #Matchday\n', '13/01/18, 09:48 - Jayesh-CSE: \xf0\x9f\xa4\xab\n', '13/01/18, 09:48 - Uddeshya Singh: \xf0\x9f\x99\x82\n', '13/01/18, 09:48 - Siddarth-IT: Yesss\n', '13/01/18, 09:49 - Siddarth-IT: \xe2\x9a\xbd\xe2\x9a\xbd\xe2\x9a\xbd\n', '13/01/18, 09:49 - Jayesh-CSE: \xf0\x9f\x90\xa2\xf0\x9f\x90\xa2\xf0\x9f\x90\xa2\n', '13/01/18, 09:49 - Uddeshya Singh: Yahi score hoga. 3-0 \xf0\x9f\x99\x82\n', '13/01/18, 09:50 - Siddarth-IT: And the sides\n', '13/01/18, 09:54 - Manvendra-ET: 21-0 maybe good one\n', '13/01/18, 09:55 - Jayesh-CSE: \xf0\x9f\x98\x86\xf0\x9f\x98\x86\xf0\x9f\x98\x86\n', '13/01/18, 09:55 - Abhishek-ME: Team B match today\n', '13/01/18, 09:55 - Manvendra-ET: Yup finals\n', '13/01/18, 09:56 - Abhishek-ME: 1st year should rock\xf0\x9f\x91\x8d\xf0\x9f\x8f\xbb\n', '13/01/18, 09:56 - Jayesh-CSE: \xf0\x9f\x98\x8e\xf0\x9f\x91\x8d\xf0\x9f\x8f\xbb\n', '13/01/18, 09:56 - Manvendra-ET: \xf0\x9f\x91\x8d\xf0\x9f\x91\x8d\xf0\x9f\xa4\x9f\xf0\x9f\xa4\x9f\n', "13/01 ...

# %%
users=[]
def getAuxStr(arr):
    aux=""
    for i in arr:
        aux=aux+" "+str(i)
    return aux.strip()
def findUser(arr):
    for i in range(2,len(arr)):
        if arr[i][-1]==":":
            aux_string=getAuxStr(arr[3:i])
            users.append((aux_string+" "+arr[i].split(':')[0]).strip())
            
for i in aux:
    findUser(i.split())

# %%
print users
# Out:
# ['Vasu Dev-129', 'Vasu Dev-129', 'Vasu Dev-129', 'Vasu Dev-129', 'Gaurav-IT', '\xe2\x80\xaa+91 90585 60689\xe2\x80\xac', 'Pranav - 135', 'Vasu Dev-129', 'Vasu Dev-129', 'Vasu Dev-129', 'Vasu Dev-129', 'Vasu Dev-129', 'Gaurav-IT', 'Abhishek-ME', 'Abhishek-ME', 'Vasu Dev-129', 'Vasu Dev-129', 'Jayesh-CSE', 'Pranav Awasthi-IT', '\xe2\x80\xaa+91 90585 60689\xe2\x80\xac', 'Pranav - 135', 'Vasu Dev-129', 'Vasu Dev-129', 'Abhishek-ME', 'Gaurav-IT', 'Jayesh-CSE', 'Siddarth-IT', 'Gaurav-IT', 'Vasu Dev-129', 'Vasu Dev-129', 'Jayesh-CSE', 'Siddarth-IT', 'Jayesh-CSE', 'Jayesh-CSE', 'Jayesh-CSE', 'Vasu Dev-129', 'Jayesh-CSE', 'Siddarth-IT', 'Siddarth-IT', 'Jayesh-CSE', 'Siddarth-IT', 'Gaurav-IT', 'Vasu Dev-129', 'Jayesh-CSE', 'Uddeshya Singh', 'Siddarth-IT', 'Siddarth-IT', 'Jayesh-CSE', 'Uddeshya Singh', 'Siddarth-IT', 'Manvendra-ET', 'Jayesh-CSE', 'Abhishek-ME', 'Manvendra-ET', 'Abhishek-ME', 'Jayesh-CSE', 'Manvendra-ET', 'Pranav Awasthi-IT', 'Siddarth-IT', 'Pranav Awasthi-IT', 'Shivansh-IT', 'Siddarth-IT', 'Pranav - 135', 'Pranav Awasthi-IT', 'Pranav - 135', '\xe2\x80\xaa+91 90585 60689\xe2\x80\xac', 'Pranav - 135', 'Pranav - 135', 'Pranav - 135', 'Pranav - 135', '\xe2\x80\xaa+91 90585 60689\xe2\x80\xac', '\xe2\x80\xaa+91 90585 60689\xe2\x80\xac', '\xe2\x80\xaa+91 90585 60689\xe2\x80\xac', '\xe2\x80\xaa+91 93681 75868\xe2\x80\xac', 'Pranav Awasthi-IT', 'Shivansh-IT', 'Shivansh-IT', 'Pranav Awasthi-IT', 'Pranav Awasthi-IT', '\xe2\x80\xaa+91 90585 60689\xe2\x80\xac', 'Shivansh-IT', 'Shivansh-IT', 'Jayesh-CSE', 'Pranav Awasthi-IT', 'Uddeshya Singh', 'Pranav Awasthi-IT', 'Uddeshya Singh', 'Uddeshya Singh', 'Pranav Awasthi-IT', 'Pranav Awasthi-IT', 'Pranav Awasthi-IT', 'Vasu Dev-129', 'Vasu Dev-129', 'Jayesh-CSE', 'Vasu Dev-129', 'Vasu Dev-129', 'Vasu Dev-129', 'Siddarth-IT', 'Siddarth-IT', 'Gaurav-IT', 'Vasu Dev-129', 'Siddarth-IT', 'Siddarth-IT', 'Siddarth-IT', 'Siddarth-IT', 'Siddarth-IT', 'Gaurav-IT', 'Gaurav-IT', 'Gaurav-IT', 'Siddarth-IT', 'Siddarth-IT', 'Siddarth-IT', 'Gaurav-IT', 'Gaurav-IT', 'Gaurav-IT', 'Siddarth-IT', 'Gaurav-IT', 'Aditya-CSE', 'Siddarth-IT', 'Pranav Awasthi-IT', 'Jayesh-CSE', 'Uddeshya Singh', 'Jayesh-CSE', 'Uddeshya Singh', 'Jayesh-CSE', 'Uddeshya Singh', 'Jayesh-CSE', 'Jayesh-CSE', 'Jayesh-CSE', 'Uddeshya Singh', 'Siddarth-IT', 'Vasu Dev-129', 'Vasu Dev-129', 'Siddarth-IT', 'Vasu Dev-129', 'Siddarth-IT', 'Gaurav-IT', 'Siddarth-IT', 'Siddarth-IT', 'Siddarth-IT', 'Siddarth-IT', 'Siddarth-IT', 'Siddarth-IT', 'Siddarth-IT', 'Siddarth-IT', 'Siddarth-IT', 'Siddarth-IT', 'Siddarth-IT', 'Uddeshya Singh', 'Jayesh-CSE', 'Jayesh-CSE', 'Pranav Awasthi-IT', 'Jayesh-CSE', 'Jayesh-CSE', 'Siddarth-IT', 'Jayesh-CSE', 'Siddarth-IT', 'Shivansh-IT', 'Jayesh-CSE', 'Pranav Awasthi-IT', 'Siddarth-IT', 'Jayesh-CSE', 'Siddarth-IT', 'Abhishek-ME', 'Shivansh-IT', 'Siddarth-IT', 'Siddarth-IT', 'Jayesh-CSE', 'Jayesh-CSE', 'Gaurav-IT', 'Uddeshya Singh', 'Jayesh-CSE', 'Pranav - 135', '\xe2\x80\xaa+91 94550 77270\xe2\x80\xac', 'Aditya-CSE', 'Siddarth-IT', 'Jayesh-CSE', 'Aditya-CSE', '\xe2\x80\xaa+91 73804 89895\xe2\x80\xac', 'Siddarth-IT', 'Siddarth-IT', 'Jayesh-CSE', 'Pranav Awasthi-IT', 'Gaurav-IT', 'Vasu Dev-129', '\xe2\x80\xaa+91 90585 60689\xe2\x80\xac', 'Siddarth-IT', 'Siddarth-IT', 'Shivansh-IT', 'Shivansh-IT', 'Siddarth-IT', 'Siddarth-IT', 'Siddarth-IT', 'Shivansh-IT', 'Shivansh-IT: Clusters are', 'Shivansh-IT', 'Pranav Awasthi-IT', 'Gaurav-IT', 'Pranav Awasthi-IT', 'Shivansh-IT', 'Shivansh-IT', 'Siddarth-IT', 'Siddarth-IT', 'Shivansh-IT', 'Shivansh-IT', 'Shivansh-IT', 'Uddeshya Singh', 'Shivansh-IT', 'Vasu Dev-129', 'Gaurav-IT', 'Gaurav-IT', 'Dhruv Kaul - CSE', 'Uddeshya Singh', 'Siddarth-IT', 'Siddarth-IT: Rules', 'Siddarth-IT', 'Gaurav-IT', 'Siddarth-IT', 'Shivansh-IT', 'Shivansh-IT', 'Shivansh-IT', 'Shivansh-IT', 'Pranav Awasthi-IT', 'Gaurav-IT', 'Gaurav-IT', 'Pranav Awasthi-IT', 'Siddarth-IT', 'Siddarth-IT', 'Siddarth-IT', 'Siddarth-IT', 'Gaurav-IT', 'Vasu Dev-129', 'Siddarth-IT', 'Vasu Dev-129', 'Siddarth-IT', 'Siddarth-IT', 'Sidd ...

# %%
for i in set(users):
    print i
# Out:
# ‪+91 90585 60689‬
# ‪+91 73804 89895‬
# Pranav - 135
# Dhruv Kaul - CSE: Abe
# ‪+91 88004 18826‬
# Jayesh-CSE
# Uddeshya Singh
# Abhishek-ME
# Gaurav-IT
# Jayesh-CSE: BREAKING
# ‪+91 94550 77270‬
# Dhruv Kaul - CSE
# ‪+91 88826 66442‬
# Vasu Dev-129
# Shivansh-IT
# Jayesh-CSE: Paulinho
# Dhruv Kaul - CSE: Luckily- Bought a *Manchester City* Jersey today
# ‪+91 99367 90544‬
# Manvendra-ET
# Pranav Awasthi-IT
# Shivansh-IT: Clusters are
# Anik Gupta - 4 (CSE)
# Siddarth-IT
# ‪+91 93681 75868‬
# Kavish-ME
# Aditya-CSE
# Tarun-ET
# Siddarth-IT: Rules

# %%
threshold=5
verified=[]
for i in set(users):
    count=0
    for j in users:
        if i==j:
            count+=1
    if count>threshold:
        verified.append(i)

# %%
print verified
# Out:
# ['\xe2\x80\xaa+91 90585 60689\xe2\x80\xac', 'Pranav - 135', 'Jayesh-CSE', 'Uddeshya Singh', 'Abhishek-ME', 'Gaurav-IT', 'Dhruv Kaul - CSE', 'Vasu Dev-129', 'Shivansh-IT', '\xe2\x80\xaa+91 99367 90544\xe2\x80\xac', 'Manvendra-ET', 'Pranav Awasthi-IT', 'Anik Gupta - 4 (CSE)', 'Siddarth-IT', 'Kavish-ME', 'Aditya-CSE', 'Tarun-ET']
